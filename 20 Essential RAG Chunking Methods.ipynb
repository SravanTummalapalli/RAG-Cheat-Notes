# %% [markdown]
# # 20 Essentail RAG Chunking Methods

# %% [markdown]
# ## What is Chunking?

# %% [markdown]
# Chunking means **splitting large text into smaller parts (chunks)** so AI can understand better.
#
# Like dividing a long story into chapters!
#
# **Without chunking** -> AI forgets the begining.
#
# **with chunking** -> AI remembers what matters.

# %% [markdown]
# ### Why bad Chunkings Fails

# %% [markdown]
# **Bad chunking = AI confusion**
#
# - Breaks sentences halfway
# - Loses topic meaning
# - Gives wrong answers
#
# **Example:**
#
# if you cut **"The cat sat on the mat."** -> into **"The cat s" and "at on the mat"** -> meaning is lost!

# %% [markdown]
# ### Why Good Chunking Help
#
# Good chunking = AI clarity
#
# - Keeps sentences complete
# - Maintains flow
# - Gives correct answers
#
# **Example:**
#
# Reading one full paragraph at a time makes sense- not random half lines!

# %% [markdown]
# ### The 20 Chunking Techniques

# %% [markdown]
# 1. Fixed-size
# 2. Sentence
# 3. Paragraph
# 4. Sliding window
# 5. Semantic
# 6. Recursive
# 7. Structure-aware
# 8. Code block
# 9. Query-aware dynamic
# 10. Hybrid
# 11. Context-enriched
# 12. Token-based
# 13. Agentic
# 14. Page-based
# 15. Table-aware
# 16. Image-associated
# 17. Event-based
# 18. Citation-aware
# 19. Hierarchical
# 20. Audio/Text alignment

# %% [markdown]
# ## 1. Fixed-Size Chunking

# %% [markdown]
# Text is split into **equal-sized parts** (like every 300 words)
#
# - Simple, fast
# - May break meaning mid-sentence
#
# **Example:**
#
# A 900-word story -> split into 3 equal (300-word parts)

# %% [markdown]
# ## 2. Sentence-Based Chunking

# %% [markdown]
# Each chunking= one full sentence.
#
# - Keeps meaning complete
# - May lose wider context between sentences
#
# **Example:**
#
# "Dogs bark." -> Chunk 1
#
# "Cats meow." -> Chunk 2

# %% [markdown]
# ## 3. Paragraph-Based Chunking

# %% [markdown]
# Splits text by pragraph breaks.
#
# - Natural seperation of ideas.
# - Long paragraphs may exceed limits.
#
# **Example:**
#
# Paragraph 1: "Plants make food."
#
# Paragraph 2: "Animals eat plats."

# %% [markdown]
# ### 4. Sliding Window Chunking

# %% [markdown]
# Chunks overlap slightly to keep flow.
#
# - Keeps context
# - Repeats some text
#
# **Example:**
#
# Chunk 1: Lines 1-5
#
# Chunk 2: Lines 4-8(overlaps 4-5)

# %% [markdown]
# ### 5. Semantic Chunking

# %% [markdown]
# AI splits text by meaning or topic.
#
# - Very accurate
# - Slower
#
# **Example:**
#
# Text about "Earth" and "Mars" -> become two chunks by topic.

# %% [markdown]
# ### 6. Recursive Chunking

# %% [markdown]
# Splits large text step by step
#
# Document -> Section -> Paragraph -> Sentence.
#
# - Flexible
# - Needs documents structure
#
# **Example:**
#
# Book -> Chapter -> Paragraph -> Line

# %% [markdown]
# ### 7. Structure-Aware Chunking

# %% [markdown]
# Users **documents structure** like headings, lists or tags.
#
# - Best for websites or reports
# - Needs clean formating
#
# **Example:**
#
# HTML <h1>, <h2>, <p> -> become seperate chunks.

# %% [markdown]
# ### 8. Code Block Chunking

# %% [markdown]
# Splits text by **functions, Classes or Methods** in code.
#
# - Keeps logic complete
# - Hard for mixed text+code docs
#
# **Example:**
#
# Chunk 1: def addd_numbers()
#
# Chunk 2: def subtract_numbers()

# %% [markdown]
# ### 9. Query-Aware Dynamic Chunking

# %% [markdown]
# AI changes chunkings style **based on your question.**
#
# - Most relevant results
# - Complex to build
#
# **Example:**
#
# If you ask "Loan Process", it reads only loan-related chuncks.

# %% [markdown]
# ### 10. Hybrid Chunking

# %% [markdown]
# Combines two or more methods.
#
# - Best of both worlds
# - Setup is complex
#
# **Example:**
#
# Use sematic + sliding window -> meaning + context together.

# %% [markdown]
# ### 11. Context-Enriched Chunking

# %% [markdown]
# Adds extra info like title or source to each chunk.
#
# - Improves traceability
# - Uses more tokens
#
# **Example:**
#
# "Chapter 2- Photosynthesis: plants make food from light."

# %% [markdown]
# ### 12. Token-Based Chunking

# %% [markdown]
# AI reads "tokens," not words.
#
# Splits exactly by token limit (like 512 or 1024)
#
# - Prevents overflow
# - May break grammer
#
# **Example:**
#
# Model fits 1000 tokens -> each chunk = 1000-token portion.

# %% [markdown]
# ### 13. Agentic Chunking

# %% [markdown]
# AI iteself decides where to cut based on structure or meaning.
#
# - Smart and adaptive
# - Computationally heavy
#
# **Example:**
#
# LLM splits a 20-page report into logical 5-topic groups.

# %% [markdown]
# ### 14. Page-Based Chunking

# %% [markdown]
# Each **page of a PDF or scan** is one chunk.
#
# - Keeps layout and numbering
# - Not meaning-based
#
#
# **Example:**
#
# Page 1 -> Chunk 1
#
# Page 2 -> CHunk 2

# %% [markdown]
# ### 15. Table-Aware Chunking

# %% [markdown]
# Splits tables logically by **rows, columns or headers.**
#
# - Great for data-heavy files
# - Needs pattern detection
#
# **Example:**
#
# Chunk 1: Rows 1-5
#
# Chunk 2: Rows 6-10

# %% [markdown]
# ### 16. Image-Associated Chunking

# %% [markdown]
# Pairs images with nearby text or captions.
#
# - Perfect for multmodel RAG
# - Requires OCR or captioning
#
# **Example:**
#
# Image of a volcano + text "Mount Fuji erruption" -> 1 chunk.

# %% [markdown]
# ### 17. Event-Based Chunking

# %% [markdown]
# Splits text by **time or event markers** (like timestaps).
#
# - Keeps chronological flow
# - Needs structured logs or transcripts
#
# **Example:**
#
# [10:00] Meeting start -> Chunk 1
#
# [10:30] Discussion -> Chunk 2

# %% [markdown]
# ### 18. Citation-Aware Chunking

# %% [markdown]
# Keeps **references and citation** with the related text.
#
# - Useful for legal or research papers
# - Increases chunk size
#
# **Example:**
#
# "Quantum theory [Einstein, 1905] explains energy behavior."

# %% [markdown]
# ### 19. Hierarchical chunking

# %% [markdown]
# Creates multi-level chunks:
#
# Sentence -> Paragraph -> Section -> Document.
#
# - Supports flexible retrieval
# - Complex to manage
#
# **Example:**
#
# You can search at "section level" or "paragraph level."

# %% [markdown]
# ### 20. Audio/Text Alignment Chunking

# %% [markdown]
# Used in speech data- align chunks with timestaps or speakers.
#
# - Keeps voice context
# - Needs audio timing
#
# **Example:**
#
# Speaker 1 (00:00-01:00) -> Chunk 1
#
# Speaker 2 (01:00-02:00) -> Chunk 2

# %% [markdown]
# ![Screenshot 2026-02-21 at 5.46.05 PM.png](attachment:04815256-805b-4521-bccd-708809b3b1c3.png)

# %% [markdown]
# **Chunking is how we teach AI where to pause and think.**
#
# When chunking goes wrong -> means breaks
#
# When meaning breaks -> retrieval fails.
#
# And when retrieval fails -> hallucinations begins
#
#
# **Bad Chunking** slightly causes:
#
# - sentences to break halfway
# - topics to lose continuity
# - irrelevant context to be retrieved
# - confident but incorrect answers
#
# **Good Chunking** helps your RAG systemL
#
# - Preserve meaning and flow
# - Retrieve only what matters
# - Stay calm and accurate in production
# - Feel reliable instead of random
#
#
# This is why chunking is not just preprocessing.
#
# It's an architecture decision that directly impacts trust, accuracy and cost.

# %% [markdown]
# ### Final takeaway

# %% [markdown]
# Chunking is how you teach your AI where to pause and think.
#
# If you chunk wrongly - AI confuses facts.
#
# If you chunk wisely - AI becomes accurate, calm and smart.
